# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import tqdm
import h5py
import numpy as np
import tensorflow as tf
#import tensorflow_addons as tfa
import skimage.transform as st
import skimage.filters as sf
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

# %%
# Select global values for the normalisation
min_value = 0.01
max_value = 0.90
npix = 192

# %%
# Gaussian smoothing of binned images
sigma_gauss = 0.0

# These give the lower and upper cut values for each map
min_feature = np.array([5.5,5.5,4.0,-0.5,-10.0,2.5])
max_feature = np.array([9.5,8.5,7.5,1.14,-1.5,6.5])
cut_feature = 10.**np.array([5.5,5.5,4.0,-0.5,-10.0,2.5])
min_feature[3] = 10.**min_feature[3]
max_feature[3] = 10.**max_feature[3]
min_feature[4] = 10.**min_feature[4]
max_feature[4] = 10.**max_feature[4]

# %%
max_label = -15.5
min_label = -21.5

# %% [markdown]
# # First the features

# %%
# Load file for features
image_file = h5py.File('images_intrinsic_binned.h5','r')

# Get all systems (galaxies) in this file
system_names = list(image_file.keys())
print(f'System Names = {system_names}\n')


        
map_names = image_file[list(image_file.keys())[0]][list(image_file[list(image_file.keys())[0]].keys())[0]].attrs['Maps']
nmaps = len(map_names)
print(f'Map Names ={map_names}\n')

X = np.empty((0, npix, npix, nmaps))

for system_name in system_names:
    system = image_file[system_name]
    projection_names = list(system.keys())
    for projection_name in projection_names:
        # Get full image
        full_image = np.array(system[projection_name])
        # Clip the image values
        for i in range(nmaps): full_image[:,:,i] = np.where(full_image[:,:,i] < cut_feature[i], cut_feature[i], full_image[:,:,i])
        # Get log surface density
        full_image[:,:,0] = np.log10(full_image[:,:,0])
        full_image[:,:,1] = np.log10(full_image[:,:,1])
        full_image[:,:,2] = np.log10(full_image[:,:,2])
        full_image[:,:,5] = np.log10(full_image[:,:,5])
        # Normalize and Clip
        full_image = (full_image - min_feature) / (max_feature - min_feature) * (max_value - min_value) + min_value 
        full_image[full_image < min_value] = min_value
        full_image[full_image > max_value] = max_value
        # Resize
        full_image = st.resize(full_image,(npix,npix),order=3,anti_aliasing=True,preserve_range=True)
        # Combine
        X = np.concatenate([X, full_image.reshape(1, npix, npix, nmaps)], axis=0)
            

X = np.transpose(X, (0,2,1,3)).astype(np.float32)
print(X.shape, X.min(), X.max(), X.mean())

image_file.close()
# Out:
# System Names = ['g1.08e11', 'g1.12e12', 'g1.37e11', 'g1.52e11', 'g1.59e11', 'g1.77e12', 'g1.92e12', 'g2.41e11', 'g2.42e11', 'g2.57e11', 'g2.79e12', 'g3.06e11', 'g3.49e11', 'g5.38e11', 'g6.96e11', 'g7.08e11', 'g7.55e11', 'g7.66e11', 'g8.13e11', 'g8.26e11']
#
# Map Names =['Sigma_stars' 'Sigma_gas' 'Sigma_SFR' 'Mean_age' 'Mean_metals' 'Mean_T']
#
# (219, 192, 192, 6) 0.01 0.9 0.2910876

# %% [markdown]
# # And now the labels

# %%
# Load file for labels
image_file = h5py.File('images_withdust_AB.h5','r')

# Get all systems (galaxies) in this file
system_names = list(image_file.keys())
print(f'System Names = {system_names}\n')


filter_names = image_file[list(image_file.keys())[0]][list(image_file[list(image_file.keys())[0]].keys())[0]].attrs['Filters']
nfilters = len(filter_names)
print(f'Filter Names ={filter_names}\n')

y = np.empty((0, npix, npix, nfilters))

for system_name in system_names:
    system = image_file[system_name]
    projection_names = list(system.keys())
    for projection_name in projection_names:
        # Get full image
        full_image = np.array(system[projection_name])
        # Clip the image values
        full_image = np.where(full_image < 10.**min_label, 10.**min_label, full_image)
        # Get log surface density
        full_image = np.log10(full_image)
        # Normalize and clip
        full_image = (full_image - min_label) / (max_label - min_label) * (max_value - min_value) + min_value 
        full_image[full_image < min_value] = min_value
        full_image[full_image > max_value] = max_value
        # Resize
        full_image = st.resize(full_image,(npix,npix),order=3,anti_aliasing=True,preserve_range=True)
        # Combine
        y = np.concatenate([y, full_image.reshape(1, npix, npix, nfilters)], axis=0)
              

y = np.transpose(y, (0,2,1,3)).astype(np.float32)
print(y.shape, y.min(), y.max(), y.mean())

image_file.close()
# Out:
# System Names = ['g1.08e11', 'g1.12e12', 'g1.37e11', 'g1.52e11', 'g1.59e11', 'g1.77e12', 'g1.92e12', 'g2.41e11', 'g2.42e11', 'g2.57e11', 'g2.79e12', 'g3.06e11', 'g3.49e11', 'g5.38e11', 'g6.96e11', 'g7.08e11', 'g7.55e11', 'g7.66e11', 'g8.13e11', 'g8.26e11']
#
# Filter Names =['u' 'g' 'r' 'i' 'z']
#
# (219, 192, 192, 5) 0.01 0.9 0.15017515

# %%
nr = 31
mm = 5

plt.figure(figsize=(10,20))

ax1 = plt.subplot(1,2,1)
ax2 = plt.subplot(1,2,2)

ax1.imshow(X[nr,:,:,mm], vmin=min_value, vmax=max_value)
ax2.imshow(np.transpose(y[nr],(0,1,2))[:,:,[2,1,0]], vmin=min_value, vmax=max_value)

for ax in [ax1,ax2]:
    ax.tick_params(labelleft=False, labelbottom=False, labeltop=False, labelright=False)
    ax.set_xticks([])
    ax.set_yticks([])
plt.subplots_adjust(left=0.0, right=1.0, bottom=0.0, top=1.0, hspace=0.0, wspace=0.0)

# %% [markdown]
# ## building U-Net Model

# %%
width = 192
height = 192
channels = 6

# %%
inputs = tf.keras.layers.Input((width, height, channels))

# %%
# Encoding path


c1 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
p1 = tf.keras.layers.MaxPool2D((2, 2))(c1)

c2 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
p2 = tf.keras.layers.MaxPool2D((2, 2))(c2)

c3 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3 = tf.keras.layers.Dropout(0.2)(c3)
c3 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
p3 = tf.keras.layers.MaxPool2D((2, 2))(c3)

c4 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
c4 = tf.keras.layers.Dropout(0.2)(c4)
c4 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
p4 = tf.keras.layers.MaxPool2D(pool_size=(2, 2))(c4)

#c5 = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
#c5 = tf.keras.layers.Dropout(0.2)(c5)
#c5 = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)
#p5 = tf.keras.layers.MaxPool2D(pool_size=(2, 2))(c5)

# %%
# Decoding path


u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(1, 1), padding='same')(c4)
u6 = tf.keras.layers.concatenate([u6, c4])
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
c6 = tf.keras.layers.Dropout(0.2)(c6)
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = tf.keras.layers.concatenate([u7, c3])
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
c7 = tf.keras.layers.Dropout(0.2)(c7)
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = tf.keras.layers.concatenate([u8, c2])
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
c8 = tf.keras.layers.Dropout(0.1)(c8)
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

u9 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = tf.keras.layers.concatenate([u9, c1])
c9 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
c9 = tf.keras.layers.Dropout(0.1)(c9)
c9 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

# %%
outputs = tf.keras.layers.Conv2D(5, (3,3), activation='sigmoid', padding='same')(c9)

# %%
print('Inputs shape: ', inputs.shape)
print('Output shape: ', outputs.shape)
# Out:
# Inputs shape:  (None, 192, 192, 6)
# Output shape:  (None, 192, 192, 5)

# %%
model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
optimizer = tf.keras.optimizers.Adam(lr=0.001)
model.compile(optimizer=optimizer, loss='MSE')
model.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 192, 192, 6) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 192, 192, 32) 1760        input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 192, 192, 32) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 192, 192, 32) 9248        dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 96, 96, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 96, 96, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 96, 96, 64)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 96, 96, 64)   36928       dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 48, 48, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 48, 48, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 48, 48, 128)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 48, 48, 128)  147584      dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 24, 24, 128)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 24, 24, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 24, 24, 256)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 24, 24, 256)  590080      dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 24, 24, 128)  131200      conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 24, 24, 384)  0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 24, 24, 128)  442496      concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 24, 24, 128)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 24, 24, 128)  147584      dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 48, 48, 64)   32832       conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 48, 48, 192)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 48, 48, 64)   110656      concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 48, 48, 64)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 48, 48, 64)   36928       dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 96, 96, 32)   8224        conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 96, 96, 96)   0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 96, 96, 32)   27680       concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 96, 96, 32)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 96, 96, 32)   9248        dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 192, 192, 32) 4128        conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 192, 192, 64) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 192, 192, 32) 18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 192, 192, 32) 0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 192, 192, 32) 9248        dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 192, 192, 5)  1445        conv2d_15[0][0]
# ==================================================================================================
# Total params: 2,153,253
# Trainable params: 2,153,253
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.save('saved model')
callbacks = [
    tf.keras.callbacks.ModelCheckpoint('logs/model.{epoch:03d}-{val_loss:.6f}.h5', verbose=1, monitor = 'val_loss', save_best_only = True, save_weights_only = True),
    tf.keras.callbacks.EarlyStopping(patience = 35, monitor = 'val_loss'),
    tf.keras.callbacks.TensorBoard(log_dir = 'logs')
]
# Out:
# INFO:tensorflow:Assets written to: C:/Users/simin/Documents/GitHub/Thesis/saved model\assets

# %%
results = model.fit(X,y, validation_split=0.20, batch_size=10, epochs=300, callbacks=callbacks)
# Out:
# Epoch 1/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 00001: val_loss improved from inf to 0.00391, saving model to logs\model.001-0.003910.h5
# 18/18 [==============================] - 52s 3s/step - loss: 0.0056 - val_loss: 0.0039
# Epoch 2/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 00002: val_loss improved from 0.00391 to 0.00377, saving model to logs\model.002-0.003775.h5
# 18/18 [==============================] - 63s 4s/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 3/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00003: val_loss did not improve from 0.00377
# 18/18 [==============================] - 67s 4s/step - loss: 0.0033 - val_loss: 0.0041
# Epoch 4/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00004: val_loss did not improve from 0.00377
# 18/18 [==============================] - 72s 4s/step - loss: 0.0031 - val_loss: 0.0039
# Epoch 5/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00005: val_loss did not improve from 0.00377
# 18/18 [==============================] - 71s 4s/step - loss: 0.0030 - val_loss: 0.0038
# Epoch 6/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 00006: val_loss improved from 0.00377 to 0.00336, saving model to logs\model.006-0.003362.h5
# 18/18 [==============================] - 75s 4s/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 7/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 00007: val_loss did not improve from 0.00336
# 18/18 [==============================] - 96s 5s/step - loss: 0.0029 - val_loss: 0.0046
# Epoch 8/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00008: val_loss improved from 0.00336 to 0.00257, saving model to logs\model.008-0.002566.h5
# 18/18 [==============================] - 69s 4s/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 9/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00009: val_loss did not improve from 0.00257
# 18/18 [==============================] - 68s 4s/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 10/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 00010: val_loss did not improve from 0.00257
# 18/18 [==============================] - 67s 4s/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 11/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00011: val_loss improved from 0.00257 to 0.00244, saving model to logs\model.011-0.002440.h5
# 18/18 [==============================] - 68s 4s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 12/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00012: val_loss improved from 0.00244 to 0.00231, saving model to logs\model.012-0.002305.h5
# 18/18 [==============================] - 72s 4s/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 13/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00013: val_loss improved from 0.00231 to 0.00226, saving model to logs\model.013-0.002262.h5
# 18/18 [==============================] - 71s 4s/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 14/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 00014: val_loss did not improve from 0.00226
# 18/18 [==============================] - 68s 4s/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 15/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 00015: val_loss did not improve from 0.00226
# 18/18 [==============================] - 71s 4s/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 16/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 00016: val_loss did not improve from 0.00226
# 18/18 [==============================] - 67s 4s/step - loss: 0.0023 - val_loss: 0.0029
# Epoch 17/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 00017: val_loss improved from 0.00226 to 0.00225, saving model to logs\model.017-0.002254.h5
# 18/18 [==============================] - 71s 4s/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 18/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00018: val_loss improved from 0.00225 to 0.00217, saving model to logs\model.018-0.002173.h5
# 18/18 [==============================] - 72s 4s/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 19/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00019: val_loss improved from 0.00217 to 0.00204, saving model to logs\model.019-0.002038.h5
# 18/18 [==============================] - 67s 4s/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 20/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 00020: val_loss improved from 0.00204 to 0.00191, saving model to logs\model.020-0.001909.h5
# 18/18 [==============================] - 74s 4s/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 21/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 00021: val_loss did not improve from 0.00191
# 18/18 [==============================] - 70s 4s/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 22/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 00022: val_loss did not improve from 0.00191
# 18/18 [==============================] - 73s 4s/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 23/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 00023: val_loss improved from 0.00191 to 0.00183, saving model to logs\model.023-0.001832.h5
# 18/18 [==============================] - 71s 4s/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 24/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00024: val_loss did not improve from 0.00183
# 18/18 [==============================] - 67s 4s/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 25/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00025: val_loss did not improve from 0.00183
# 18/18 [==============================] - 66s 4s/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 26/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00026: val_loss did not improve from 0.00183
# 18/18 [==============================] - 63s 4s/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 27/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00027: val_loss improved from 0.00183 to 0.00179, saving model to logs\model.027-0.001788.h5
# 18/18 [==============================] - 64s 4s/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 28/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00028: val_loss improved from 0.00179 to 0.00176, saving model to logs\model.028-0.001762.h5
# 18/18 [==============================] - 65s 4s/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 29/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00029: val_loss did not improve from 0.00176
# 18/18 [==============================] - 68s 4s/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 30/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00030: val_loss did not improve from 0.00176
# 18/18 [==============================] - 63s 4s/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 31/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00031: val_loss did not improve from 0.00176
# 18/18 [==============================] - 63s 4s/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 32/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00032: val_loss did not improve from 0.00176
# 18/18 [==============================] - 63s 4s/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 33/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00033: val_loss did not improve from 0.00176
# 18/18 [==============================] - 64s 4s/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 34/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00034: val_loss did not improve from 0.00176
# 18/18 [==============================] - 63s 4s/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 35/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00035: val_loss improved from 0.00176 to 0.00168, saving model to logs\model.035-0.001683.h5
# 18/18 [==============================] - 64s 4s/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 36/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00036: val_loss did not improve from 0.00168
# 18/18 [==============================] - 63s 3s/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 37/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00037: val_loss did not improve from 0.00168
# 18/18 [==============================] - 68s 4s/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 38/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00038: val_loss improved from 0.00168 to 0.00167, saving model to logs\model.038-0.001666.h5
# 18/18 [==============================] - 75s 4s/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 39/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00039: val_loss did not improve from 0.00167
# 18/18 [==============================] - 71s 4s/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 40/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00040: val_loss did not improve from 0.00167
# 18/18 [==============================] - 72s 4s/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 41/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00041: val_loss did not improve from 0.00167
# 18/18 [==============================] - 74s 4s/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 42/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00042: val_loss did not improve from 0.00167
# 18/18 [==============================] - 76s 4s/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 43/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00043: val_loss did not improve from 0.00167
# 18/18 [==============================] - 68s 4s/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 44/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00044: val_loss did not improve from 0.00167
# 18/18 [==============================] - 68s 4s/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 45/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00045: val_loss improved from 0.00167 to 0.00163, saving model to logs\model.045-0.001629.h5
# 18/18 [==============================] - 82s 5s/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 46/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00046: val_loss did not improve from 0.00163
# 18/18 [==============================] - 74s 4s/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 47/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00047: val_loss did not improve from 0.00163
# 18/18 [==============================] - 71s 4s/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 48/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00048: val_loss did not improve from 0.00163
# 18/18 [==============================] - 67s 4s/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 49/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00049: val_loss did not improve from 0.00163
# 18/18 [==============================] - 72s 4s/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 50/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00050: val_loss improved from 0.00163 to 0.00157, saving model to logs\model.050-0.001574.h5
# 18/18 [==============================] - 68s 4s/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 51/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00051: val_loss did not improve from 0.00157
# 18/18 [==============================] - 70s 4s/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 52/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00052: val_loss did not improve from 0.00157
# 18/18 [==============================] - 66s 4s/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 53/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00053: val_loss did not improve from 0.00157
# 18/18 [==============================] - 67s 4s/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 54/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00054: val_loss did not improve from 0.00157
# 18/18 [==============================] - 76s 4s/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 55/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00055: val_loss did not improve from 0.00157
# 18/18 [==============================] - 68s 4s/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 56/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00056: val_loss did not improve from 0.00157
# 18/18 [==============================] - 67s 4s/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 57/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00057: val_loss did not improve from 0.00157
# 18/18 [==============================] - 71s 4s/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 58/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00058: val_loss did not improve from 0.00157
# 18/18 [==============================] - 68s 4s/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 59/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00059: val_loss did not improve from 0.00157
# 18/18 [==============================] - 72s 4s/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 60/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 00060: val_loss did not improve from 0.00157
# 18/18 [==============================] - 60s 3s/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 61/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00061: val_loss did not improve from 0.00157
# 18/18 [==============================] - 60s 3s/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 62/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00062: val_loss did not improve from 0.00157
# 18/18 [==============================] - 73s 4s/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 63/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00063: val_loss did not improve from 0.00157
# 18/18 [==============================] - 70s 4s/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 64/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00064: val_loss did not improve from 0.00157
# 18/18 [==============================] - 71s 4s/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 65/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 00065: val_loss did not improve from 0.00157
# 18/18 [==============================] - 71s 4s/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 66/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 00066: val_loss did not improve from 0.00157
# 18/18 [==============================] - 72s 4s/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 67/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 00067: val_loss did not improve from 0.00157
# 18/18 [==============================] - 70s 4s/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 68/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 00068: val_loss did not improve from 0.00157
# 18/18 [==============================] - 68s 4s/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 69/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 00069: val_loss improved from 0.00157 to 0.00157, saving model to logs\model.069-0.001573.h5
# 18/18 [==============================] - 68s 4s/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 70/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 00070: val_loss improved from 0.00157 to 0.00153, saving model to logs\model.070-0.001529.h5
# 18/18 [==============================] - 69s 4s/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 71/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 00071: val_loss did not improve from 0.00153
# 18/18 [==============================] - 73s 4s/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 72/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 00072: val_loss did not improve from 0.00153
# 18/18 [==============================] - 73s 4s/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 73/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 00073: val_loss did not improve from 0.00153
# 18/18 [==============================] - 70s 4s/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 74/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00074: val_loss did not improve from 0.00153
# 18/18 [==============================] - 69s 4s/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 75/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00075: val_loss did not improve from 0.00153
# 18/18 [==============================] - 67s 4s/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 76/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00076: val_loss did not improve from 0.00153
# 18/18 [==============================] - 66s 4s/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 77/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 00077: val_loss did not improve from 0.00153
# 18/18 [==============================] - 65s 4s/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 78/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 00078: val_loss improved from 0.00153 to 0.00153, saving model to logs\model.078-0.001529.h5
# 18/18 [==============================] - 66s 4s/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 79/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00079: val_loss did not improve from 0.00153
# 18/18 [==============================] - 66s 4s/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 80/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00080: val_loss did not improve from 0.00153
# 18/18 [==============================] - 66s 4s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 81/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00081: val_loss did not improve from 0.00153
# 18/18 [==============================] - 66s 4s/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 82/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00082: val_loss improved from 0.00153 to 0.00153, saving model to logs\model.082-0.001527.h5
# 18/18 [==============================] - 69s 4s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 83/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00083: val_loss did not improve from 0.00153
# 18/18 [==============================] - 67s 4s/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 84/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00084: val_loss did not improve from 0.00153
# 18/18 [==============================] - 66s 4s/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 85/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00085: val_loss did not improve from 0.00153
# 18/18 [==============================] - 66s 4s/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 86/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00086: val_loss improved from 0.00153 to 0.00146, saving model to logs\model.086-0.001459.h5
# 18/18 [==============================] - 68s 4s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 87/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00087: val_loss did not improve from 0.00146
# 18/18 [==============================] - 67s 4s/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 88/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00088: val_loss did not improve from 0.00146
# 18/18 [==============================] - 66s 4s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 89/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00089: val_loss did not improve from 0.00146
# 18/18 [==============================] - 69s 4s/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 90/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00090: val_loss did not improve from 0.00146
# 18/18 [==============================] - 85s 5s/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 91/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00091: val_loss did not improve from 0.00146
# 18/18 [==============================] - 74s 4s/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 92/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00092: val_loss did not improve from 0.00146
# 18/18 [==============================] - 80s 4s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 93/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00093: val_loss did not improve from 0.00146
# 18/18 [==============================] - 79s 4s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 94/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00094: val_loss did not improve from 0.00146
# 18/18 [==============================] - 79s 4s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 95/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00095: val_loss did not improve from 0.00146
# 18/18 [==============================] - 85s 5s/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 96/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00096: val_loss did not improve from 0.00146
# 18/18 [==============================] - 80s 4s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 97/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00097: val_loss did not improve from 0.00146
# 18/18 [==============================] - 94s 5s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 98/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00098: val_loss did not improve from 0.00146
# 18/18 [==============================] - 89s 5s/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 99/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00099: val_loss did not improve from 0.00146
# 18/18 [==============================] - 97s 5s/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 100/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00100: val_loss did not improve from 0.00146
# 18/18 [==============================] - 101s 6s/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 101/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00101: val_loss did not improve from 0.00146
# 18/18 [==============================] - 94s 5s/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 102/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00102: val_loss did not improve from 0.00146
# 18/18 [==============================] - 85s 5s/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 103/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00103: val_loss did not improve from 0.00146
# 18/18 [==============================] - 98s 5s/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 104/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00104: val_loss did not improve from 0.00146
# 18/18 [==============================] - 95s 5s/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 105/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00105: val_loss did not improve from 0.00146
# 18/18 [==============================] - 87s 5s/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 106/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00106: val_loss did not improve from 0.00146
# 18/18 [==============================] - 87s 5s/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 107/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00107: val_loss did not improve from 0.00146
# 18/18 [==============================] - 66s 4s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 108/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00108: val_loss did not improve from 0.00146
# 18/18 [==============================] - 82s 5s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 109/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00109: val_loss did not improve from 0.00146
# 18/18 [==============================] - 92s 5s/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 110/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00110: val_loss did not improve from 0.00146
# 18/18 [==============================] - 88s 5s/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 111/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00111: val_loss did not improve from 0.00146
# 18/18 [==============================] - 99s 5s/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 112/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00112: val_loss did not improve from 0.00146
# 18/18 [==============================] - 90s 5s/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 113/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00113: val_loss did not improve from 0.00146
# 18/18 [==============================] - 90s 5s/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 114/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00114: val_loss did not improve from 0.00146
# 18/18 [==============================] - 83s 5s/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 115/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00115: val_loss did not improve from 0.00146
# 18/18 [==============================] - 81s 4s/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 116/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00116: val_loss did not improve from 0.00146
# 18/18 [==============================] - 80s 4s/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 117/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00117: val_loss did not improve from 0.00146
# 18/18 [==============================] - 78s 4s/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 118/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00118: val_loss did not improve from 0.00146
# 18/18 [==============================] - 78s 4s/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 119/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00119: val_loss did not improve from 0.00146
# 18/18 [==============================] - 77s 4s/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 120/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00120: val_loss did not improve from 0.00146
# 18/18 [==============================] - 77s 4s/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 121/300
# 18/18 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00121: val_loss did not improve from 0.00146
# 18/18 [==============================] - 78s 4s/step - loss: 0.0014 - val_loss: 0.0015

# %%
from tensorflow import keras
model = keras.models.load_model('saved model')

# %%
y_pre = model.predict(X)

# %%
print(y_pre.shape)
# Out:
# (219, 192, 192, 5)

# %%
def res_calculator(image_num, filter_num):
    
    y1=y[image_num,:,:,filter_num]
    y2=y_pre[image_num,:,:,filter_num]
    error=(y1-y2/y1)
    
    y1_norm=np.linalg.norm(y1)
    y2_norm=np.linalg.norm(y2)
    error_norm=np.linalg.norm(error)/(192*192)
    return [y1_norm, y2_norm, error_norm]

# %%
l1=[]
l2=[]
l3=[]
l4=[]
l5=[]


for i in range (0,219):
    res_1=res_calculator(i, 0)
    res_2=res_calculator(i, 1)
    res_3=res_calculator(i, 2)
    res_4=res_calculator(i, 3)
    res_5=res_calculator(i, 4)
    
    l1.append(res_1[2])
    l2.append(res_2[2])
    l3.append(res_3[2])
    l4.append(res_4[2])
    l5.append(res_5[2])

# %%
x=list(range(0,219))

plt.figure(figsize=(12,10))

plt.plot(x,l1, color='purple')
plt.plot(x,l2, color='green')
plt.plot(x,l3, color='red')
plt.plot(x,l4, color='orange')
plt.plot(x,l5, color='black')

plt.title('Residuals for Different Filters', fontsize=32)
plt.ylabel('Residuals', fontsize=25)
plt.xlabel('Images', fontsize=25)
plt.rc('xtick',labelsize=16)
plt.rc('ytick',labelsize=16)

plt.legend(['Ultraviolet', 'Green', 'Red', 'Near Infrared', 'Infrared'], loc='upper left', fontsize=15)

plt.show()

# %%
l2.index(max(l2))
# Out:
# 75

# %%
l2.index(min(l2))
# Out:
# 52

# %%
nr = 52
mm = 5

plt.figure(figsize=(10,20))

ax1 = plt.subplot(1,2,1)
ax2 = plt.subplot(1,2,2)

#ax1.imshow(X[nr,:,:,mm], vmin=min_value, vmax=max_value)
ax1.imshow(np.transpose(y[nr],(0,1,2))[:,:,[2,1,0]], vmin=min_value, vmax=max_value)
ax2.imshow(np.transpose(y_pre[nr],(0,1,2))[:,:,[2,1,0]], vmin=min_value, vmax=max_value)

for ax in [ax1,ax2]:
    ax.tick_params(labelleft=False, labelbottom=False, labeltop=False, labelright=False)
    ax.set_xticks([])
    ax.set_yticks([])
plt.subplots_adjust(left=0.0, right=1.0, bottom=0.0, top=1.0, hspace=0.0, wspace=0.0)

# %%
a=results.history['loss']
del a[0]

b=results.history['val_loss']
del b[0]

plt.figure(figsize=(12,10))
plt.plot(a, color='red')
plt.plot(b, color='blue')
plt.title('model loss', fontsize=32)
plt.ylabel('loss', fontsize=25)
plt.xlabel('epoch', fontsize=25)
plt.rc('xtick',labelsize=16)
plt.rc('ytick',labelsize=16)
plt.legend(['train', 'validation'], loc='upper right', fontsize=15)

plt.show()
